# %%
import pandas as pd
train = pd.read_csv('../train.csv', sep='\t')

# %%
train
# Out:
#            paperid                                              title  \
# 0      train_00000  Hard but Robust, Easy but Sensitive: How Encod...
# 1      train_00001  An Easy-to-use Real-world Multi-objective Opti...
# 2      train_00002  Exploration of reproducibility issues in scien...
# 3      train_00003                Scheduled Sampling for Transformers
# 4      train_00004  Hybrid Forests for Left Ventricle Segmentation...
# ...            ...                                                ...
# 49995  train_49995  Copy-and-Paste Networks for Deep Video Inpainting
# 49996  train_49996  The Theorem Prover Museum -- Conserving the Sy...
# 49997  train_49997  Dynamically Generated Interfaces in XML Based ...
# 49998  train_49998  BlockLoc: Secure Localization in the Internet-...
# 49999  train_49999  Quantifiers metamorphoses. Generalizations, va...
#
#                                                 abstract categories
# ...
